# %% [markdown]
# <a href="https://colab.research.google.com/github/xinhuiiii/fin_data/blob/main/HW9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install fredapi #下載FRED的API
from fredapi import Fred #呼叫FRED套件
fred = Fred(api_key="d99654a6627f90ec37c00e507c440f7b")

# %%
data1 = fred.get_series('FPCPITOTLZGUSA') #通貨膨脹的資料

# %%
data1 = fred.get_series('FPCPITOTLZGUSA','1965')

# %%
data1.plot()
# Out:
# <Axes: >

# %%
data2 = fred.get_series('UNRATE') #失業率的資料

# %%
data2 = fred.get_series('UNRATE','2020')

# %%
data2.plot()
# Out:
# <Axes: >

# %%
data3 = fred.get_series('MICH') #預期通貨膨脹

# %%
data3 = fred.get_series('MICH','1965')

# %%
data3.plot()
# Out:
# <Axes: >

# %%
data4 = fred.get_series('T5YIFR') #預期五年期的通貨膨脹預期率

# %%
data4 = fred.get_series('T5YIFR','2020')

# %%
data4.plot()
# Out:
# <Axes: >

# %%
data2.plot()
data4.plot() #結合data2和data4的資料繪製成一張圖表
# Out:
# <ipython-input-23-4b24cde90b25>:2: FutureWarning: PeriodDtype[B] is deprecated and will be removed in a future version. Use a DatetimeIndex with freq='B' instead
#   data4.plot() #結合data2和data4的資料繪製成一張圖表
# <ipython-input-23-4b24cde90b25>:2: FutureWarning: PeriodDtype[B] is deprecated and will be removed in a future version. Use a DatetimeIndex with freq='B' instead
#   data4.plot() #結合data2和data4的資料繪製成一張圖表
# <Axes: >
